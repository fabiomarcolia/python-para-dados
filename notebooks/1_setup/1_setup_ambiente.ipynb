# %% [markdown]
# # 00_setup — Ambiente, VS Code e Jupyter
#
# ## Objetivo
# - Criar e ativar um ambiente virtual (venv)
# - Instalar dependências
# - Rodar notebooks no VS Code
#
# ---

# %% [markdown]
# ## 1) Criar venv

# %%
# !python -m venv .venv

# %% [markdown]
# ## 2) Ativar venv
#
# No terminal do VS Code:
#
# - Windows: `.venv\Scripts\activate`
# - Linux/Mac: `source .venv/bin/activate`

# %% [markdown]
# ## 3) Instalar requirements

# %%
# !python -m pip install --upgrade pip
# !pip install -r requirements.txt

# %% [markdown]
# ## 4) Registrar kernel (opcional)

# %%
# !python -m ipykernel install --user --name python-para-dados

# %% [markdown]
# ## 5) Checklist
# - [ ] `.venv` criada
# - [ ] Dependências instaladas
# - [ ] Notebook executando no VS Code
