# %% [markdown]
# # 03_pandas — Leitura, limpeza e primeiras perguntas
#
# ## Objetivo
# - Carregar um dataset
# - Fazer inspeção rápida
# - Tratar tipos, nulos e duplicados
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1) Carregar dados
# Aponte para um arquivo dentro de `dados/source/` (do repo de datasets) ou coloque um CSV pequeno em `dados/raw/`.

# %%
from pathlib import Path

BASE = Path('data')
SOURCE = BASE / 'source' / 'bases-dados-analytics-powerbi-ml'

# Exemplo: procure arquivos disponíveis
files = list(SOURCE.rglob('*.csv'))[:10]
files

# %% [markdown]
# ## 2) Ler um CSV (ajuste o caminho)

# %%
# ajuste para um arquivo real encontrado acima
# df = pd.read_csv(files[0])
# df.head()

# %% [markdown]
# ## 3) Inspeção rápida

# %%
# df.shape
# df.info()
# df.describe(include='all').T

# %% [markdown]
# ## 4) Qualidade

# %%
# df.isna().mean().sort_values(ascending=False).head(20)
# df.duplicated().sum()

# %% [markdown]
# ## Exercícios
# 1- Carregue um dataset e liste as 10 colunas com mais nulos.
# 2- Identifique colunas com tipo incorreto (ex.: número como texto).
# 3- Gere um resumo com 3 problemas de qualidade e como corrigir.
