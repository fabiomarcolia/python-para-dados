# %% [markdown]
# # Aula
#
# ## Objetivo
# -
#
# ## Pré-requisitos
# -
#
# ---

# %% [markdown]
# ## 1) Setup
# Descreva rapidamente o que será feito.

# %%
# Seu código aqui

# %% [markdown]
# ## 2) Exercícios
# 1-
# 2-
# 3-

# %% [markdown]
# ## 3) Próximos passos
# -
